# %%
from google.colab import files
from google.colab import drive
import os
import zipfile
from fastai.vision.all import *
from tensorflow import keras
from tensorflow.keras.models import load_model

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Model loading**

# %%
models_dir = '/content/drive/MyDrive/IS_project/models/official_models'

unregularized_model_filename = 'model_no_regularization_128_neurons-08-30-2024_14-40-11.keras'
regularized_model_filename = 'regularized_model-08-31-2024_13-19-12.keras'

saved_models = os.listdir(models_dir)
print('Available models:')
for model in saved_models:
  print(model)

unregularized_model = load_model(os.path.join(models_dir, unregularized_model_filename))
regularized_model = load_model(os.path.join(models_dir, regularized_model_filename))
# Out:
# Available models:
# model_no_regularization_128_neurons-08-30-2024_14-40-11.keras
# unregularized_history.json
# regularized_history.json
# regularized_model-08-31-2024_13-19-12.keras
